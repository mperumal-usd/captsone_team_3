# %%
#Mount collab drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
# Read the test labels comparison CSV file
test_labels_comparison_path = '/content/drive/MyDrive/capstone_team_3/test_labels_comparison_v1.csv'
test_labels_comparison_df = pd.read_csv(test_labels_comparison_path)

# %%
test_labels_comparison_df
# Out:
#                                                label lstm_predicted_label  \
# 0                          Piano Sonata n12 K332.mid         mz_333_3.mid
# 1                          Piano Sonata n12 K332.mid         mz_333_3.mid
# 2                          Piano Sonata n12 K332.mid         mz_333_3.mid
# 3                          Piano Sonata n12 K332.mid         mz_333_3.mid
# 4                          Piano Sonata n12 K332.mid         mz_333_3.mid
# ...                                              ...                  ...
# 210162  Piano Sonata n29 Op106 ''Hammerklavier''.mid     grieg_kobold.mid
# 210163  Piano Sonata n29 Op106 ''Hammerklavier''.mid     grieg_zwerge.mid
# 210164  Piano Sonata n29 Op106 ''Hammerklavier''.mid     grieg_zwerge.mid
# 210165  Piano Sonata n29 Op106 ''Hammerklavier''.mid     grieg_zwerge.mid
# 210166  Piano Sonata n29 Op106 ''Hammerklavier''.mid         chpn-p24.mid
#
#        gru_predicted_label
# 0             mz_332_1.mid
# 1             mz_332_1.mid
# 2             mz_332_1.mid
# 3             mz_332_1.mid
# 4             mz_332_1.mid
# ...                    ...
# 210162      liz_rhap02.mid
# 210163      liz_rhap02.mid
# 210164      liz_rhap02.mid
# 210165      liz_rhap02.mid
# 210166      liz_rhap02.mid
#
# [210167 rows x 3 columns]

# %%
test_labels_comparison_df['label'].unique()
# Out:
# array(['Piano Sonata n12 K332.mid', 'Piano Sonata n10 K330.mid',
#        'Piano Sonata n13 K333.mid', 'Piano Sonata n16 K545.mid',
#        'Piano Sonata n18 K570.mid', 'K331 Piano Sonata n11 .mid',
#        'Piano Sonata n08 K311.mid', 'K331 Piano sonata n11 3mov.mid',
#        'Piano Sonata n11 K331.mid', 'Scherzo No.2, Opus.31.mid',
#        'Chopin Nocturne Op9 No3.mid', 'Sonata op35 n1 .mid',
#        "Op.53 'Polonaise in A flat' Heroic.mid", 'Scherzo op31.mid',
#        'Nocturne op32 n2.mid', 'Sonata op35 n2 .mid',
#        'Nocturne op33 n4.mid', 'Mazurka op33 n2 Drchew.mid',
#        'chopin063.mid', 'Sonata op35 n4 .mid', 'Sonata op35 n3 .mid',
#        'Ballad op53.mid',
#        'Fur Elise_Full_K-Amin_T-variable_bothhands.mid',
#        'FurElise_4thVerse_K-Amin_T-79_bothhands.mid',
#        "Piano Sonata n21 3mov ''Waldstein''.mid",
#        "Piano Sonata n14 op27  ''Moonlight''.mid",
#        "Piano sonata n26 ''Les Adieux''.mid",
#        'FurElise_4thVerse_K-Gmin_T-63_bothhands.mid',
#        "Piano Sonata n21 2mov ''Waldstein''.mid", 'Piano Sonata n05.mid',
#        "Piano Sonata n14 op27 3mov ''Moonlight''.mid",
#        "Piano Sonata n14 op27 1mov ''Moonlight''.mid",
#        "Piano Sonata n08 op13 3mov ''Pathetique''.mid",
#        "Piano Sonata n21 1mov ''Waldstein''.mid",
#        "Piano Sonata n08 op13 2mov ''Pathetique''.mid",
#        "Piano Sonata n23 op57 2mov ''Apassionata''.mid",
#        "Piano Sonata n08 op13 1mov ''Pathetique''.mid",
#        "Piano Sonata n23 op57 1mov ''Apassionata''.mid",
#        "Piano Sonata n14 op27 2mov ''Moonlight''.mid",
#        'FurElise_Intro-2ndVers_K-Amin_T-70_bothhands.mid',
#        "Piano Sonata n23 op57 3mov ''Apassionata''.mid",
#        "Piano Sonata n29 Op106 ''Hammerklavier''.mid"], dtype=object)

# %%
test_labels_comparison_df['gru_predicted_label'].unique()
# Out:
# array(['mz_332_1.mid', 'muss_7.mid', 'pathetique_1.mid', 'mz_333_3.mid',
#        'mz_330_1.mid', 'mz_570_1.mid', 'hay_40_1.mid', 'mz_331_1.mid',
#        'haydn_33_1.mid', 'mz_333_1.mid', 'haydn_35_3.mid', 'mz_311_1.mid',
#        'haydn_43_1.mid', 'beethoven_hammerklavier_4.mid',
#        'beethoven_opus10_1.mid', 'appass_2.mid', 'scn68_12.mid',
#        'mendel_op30_2.mid', 'haydn_43_3.mid', 'mz_332_3.mid',
#        'mz_330_3.mid', 'mz_311_3.mid', 'haydn_35_1.mid',
#        'chpn_op35_3.mid', 'mz_311_2.mid', 'mz_332_2.mid',
#        'mendel_op19_1.mid', 'mz_333_2.mid', 'chpn-p6.mid',
#        'beethoven_opus10_2.mid', 'haydn_33_2.mid', 'muss_2.mid',
#        'muss_6.mid', 'alb_se5.mid', 'schumm-5.mid', 'gra_esp_3.mid',
#        'ty_august.mid', 'schubert_D935_4.mid', 'appass_1.mid',
#        'beethoven_opus22_1.mid', 'beethoven_opus90_1.mid',
#        'ty_dezember.mid', 'ty_februar.mid', 'pathetique_3.mid',
#        'chpn-p8.mid', 'chpn-p24.mid', 'mendel_op30_4.mid', 'appass_3.mid',
#        'chp_op18.mid', 'ty_november.mid', 'mond_3.mid',
#        'grieg_zwerge.mid', 'liz_rhap02.mid', 'waldstein_1.mid',
#        'beethoven_opus10_3.mid', 'grieg_kobold.mid',
#        'beethoven_hammerklavier_2.mid', 'chpn-p18.mid',
#        'mendel_op19_3.mid', 'chpn_op66.mid', 'grieg_halling.mid',
#        'beethoven_opus90_2.mid', 'schubert_D935_2.mid', 'scn16_5.mid',
#        'beethoven_opus22_4.mid', 'elise.mid', 'beethoven_opus22_2.mid',
#        'chpn-p9.mid', 'schumm-4.mid', 'scn15_9.mid', 'debussy_cc_1.mid',
#        'burg_gewitter.mid', 'mz_570_2.mid', 'waldstein_3.mid',
#        'liz_rhap15.mid', 'beethoven_les_adieux_3.mid', 'mz_545_3.mid',
#        'haydn_35_2.mid', 'mz_330_2.mid', 'pathetique_2.mid',
#        'schumm-1.mid', 'bach_850.mid', 'liz_et1.mid', 'bach_847.mid',
#        'chpn-p22.mid', 'grieg_wedding.mid', 'scn15_6.mid', 'alb_esp3.mid',
#        'chpn_op27_2.mid', 'chpn_op10_e12.mid', 'chpn_op25_e11.mid',
#        'chp_op31.mid', 'br_rhap.mid', 'schuim-1.mid', 'mz_331_3.mid',
#        'schubert_D850_1.mid', 'schuim-2.mid', 'debussy_cc_4.mid',
#        'hay_40_2.mid', 'mz_570_3.mid', 'alb_se3.mid', 'schu_143_3.mid',
#        'chpn_op7_1.mid', 'haydn_9_1.mid', 'islamei.mid', 'liz_rhap12.mid',
#        'schuim-4.mid', 'schub_d760_2.mid', 'chpn-p15.mid', 'br_im2.mid',
#        'mz_545_2.mid', 'mendel_op30_5.mid', 'schubert_D850_4.mid',
#        'liz_et_trans4.mid', 'schubert_D850_3.mid', 'waldstein_2.mid',
#        'bach_846.mid', 'mond_1.mid', 'mendel_op30_1.mid', 'alb_se4.mid',
#        'schub_d960_1.mid', 'schu_143_1.mid', 'schubert_D935_3.mid',
#        'muss_4.mid', 'bor_ps1.mid', 'muss_8.mid',
#        'beethoven_hammerklavier_3.mid', 'schumm-2.mid', 'mond_2.mid',
#        'brahms_opus1_4.mid', 'haydn_33_3.mid',
#        'beethoven_les_adieux_2.mid', 'mz_545_1.mid', 'haydn_8_1.mid',
#        'schub_d960_4.mid', 'mendel_op19_5.mid', 'chpn_op25_e2.mid',
#        'brahms_opus1_2.mid', 'mendel_op62_5.mid', 'mz_331_2.mid',
#        'chpn_op53.mid', 'haydn_7_1.mid', 'schum_abegg.mid',
#        'beethoven_opus22_3.mid', 'ty_juli.mid', 'brahms_opus1_1.mid',
#        'chpn-p16.mid', 'chpn_op33_4.mid', 'alb_esp4.mid',
#        'ty_oktober.mid', 'haydn_43_2.mid', 'burg_geschwindigkeit.mid',
#        'muss_1.mid', 'grieg_walzer.mid', 'ty_mai.mid', 'scn16_8.mid',
#        'beethoven_hammerklavier_1.mid', 'alb_se6.mid', 'liz_donjuan.mid',
#        'ty_maerz.mid', 'grieg_once_upon_a_time.mid', 'schu_143_2.mid',
#        'schubert_D850_2.mid', 'liz_et5.mid', 'alb_esp6.mid',
#        'beethoven_les_adieux_1.mid', 'burg_spinnerlied.mid',
#        'liz_et3.mid', 'grieg_waechter.mid', 'bor_ps2.mid',
#        'chpn_op25_e1.mid', 'scn15_1.mid', 'schub_d760_4.mid',
#        'liz_liebestraum.mid', 'chpn_op10_e05.mid', 'gra_esp_2.mid',
#        'grieg_spring.mid', 'scn16_7.mid', 'burg_agitato.mid',
#        'alb_se7.mid', 'muss_5.mid', 'liz_et6.mid', 'chpn_op35_2.mid',
#        'liz_et4.mid', 'liz_et_trans5.mid', 'liz_et_trans8.mid',
#        'schub_d760_3.mid', 'liz_et2.mid', 'brahms_opus1_3.mid',
#        'chpn-p12.mid', 'liz_rhap09.mid', 'debussy_cc_6.mid',
#        'liz_rhap10.mid', 'scn16_3.mid', 'chpn_op25_e3.mid', 'scn16_2.mid',
#        'deb_prel.mid', 'scn15_10.mid', 'ty_april.mid', 'chpn_op23.mid',
#        'chpn-p19.mid', 'schub_d960_3.mid', 'burg_perlen.mid',
#        'chpn_op35_1.mid', 'ty_september.mid', 'schumm-6.mid',
#        'grieg_voeglein.mid', 'schub_d760_1.mid', 'haydn_8_3.mid',
#        'mendel_op53_5.mid', 'scn15_4.mid', 'burg_quelle.mid',
#        'deb_menu.mid', 'alb_se8.mid', 'mendel_op19_4.mid', 'chpn-p21.mid',
#        'chpn_op35_4.mid', 'mendel_op62_3.mid', 'chpn_op33_2.mid',
#        'burg_trennung.mid', 'bor_ps3.mid', 'chpn-p14.mid',
#        'grieg_brooklet.mid', 'haydn_8_4.mid', 'alb_se2.mid',
#        'ty_juni.mid', 'bor_ps7.mid', 'alb_esp5.mid', 'mendel_op30_3.mid',
#        'scn15_3.mid', 'scn15_13.mid', 'schuim-3.mid', 'grieg_march.mid',
#        'scn16_6.mid', 'alb_esp1.mid', 'chpn_op27_1.mid', 'chpn-p13.mid',
#        'br_im5.mid', 'grieg_berceuse.mid', 'burg_erwachen.mid',
#        'haydn_9_3.mid', 'alb_esp2.mid', 'schubert_D935_1.mid',
#        'chpn-p2.mid', 'chpn_op25_e4.mid', 'chpn-p1.mid'], dtype=object)
